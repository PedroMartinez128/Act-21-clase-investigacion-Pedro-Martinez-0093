# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroMartinez128/Act-21-clase-investigacion-Pedro-Martinez-0093/blob/main/Act_21_clase_Investigador_Pedro_Martinez_0093.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Pedro Martinez NL = 34 Fecha 23/04/26
#
# ---
# #### Nombre de la clase 34
# * Investigador🐱‍👤
#
# ---
# ![texto del vínculo](https://raw.githubusercontent.com/PedroMartinez128/Act-21-clase-investigacion-Pedro-Martinez-0093/refs/heads/main/infoclasseinvestigador.png)

# %%
class Investigador:
    # El método __init__ es el constructor (donde nacen los atributos)
    def __init__(self, nombre, especialidad, edad):
        self.nombre = nombre          # Atributo 1
        self.especialidad = especialidad # Atributo 2
        self.edad = edad              # Atributo 3

    # Función 1: Investigar
    def investigar(self):
        print(f"{self.nombre} está realizando una investigación profunda en el área de {self.especialidad}.")

    # Función 2: Analizar
    def analizar(self):
        print(f"{self.nombre} está analizando los datos recolectados. ¡Parece que hay hallazgos importantes!")

    # Función 3: Difusión de resultados
    def difusion_de_resultados(self):
        print(f"Publicación oficial: El investigador de {self.edad} años, {self.nombre}, ha compartido sus resultados con la comunidad científica.")

# --- Creación de Objetos (Instancias) ---

# Investigador 1
investigador1 = Investigador("Dr. Aris", "Astrofísica", 45)

# Investigador 2
investigador2 = Investigador("Dra. Elena", "Biotecnología", 32)

# --- Ejecución de Funciones ---

print("--- Actividades del Investigador 1 ---")
investigador1.investigar()
investigador1.analizar()
investigador1.difusion_de_resultados()

print("\n--- Actividades del Investigador 2 ---")
investigador2.investigar()
investigador2.analizar()
investigador2.difusion_de_resultados()
print("===== programa terminado =====")
print("---software realizado por Pedro Martinez NL = 34")
# Out:
# --- Actividades del Investigador 1 ---
# Dr. Aris está realizando una investigación profunda en el área de Astrofísica.
# Dr. Aris está analizando los datos recolectados. ¡Parece que hay hallazgos importantes!
# Publicación oficial: El investigador de 45 años, Dr. Aris, ha compartido sus resultados con la comunidad científica.
#
# --- Actividades del Investigador 2 ---
# Dra. Elena está realizando una investigación profunda en el área de Biotecnología.
# Dra. Elena está analizando los datos recolectados. ¡Parece que hay hallazgos importantes!
# Publicación oficial: El investigador de 32 años, Dra. Elena, ha compartido sus resultados con la comunidad científica.
# ===== programa terminado =====
# ---software realizado por Pedro Martinez NL = 34

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/PedroMartinez128/Act-21-clase-investigacion-Pedro-Martinez-0093/refs/heads/main/Reprecentacionfunciondelcodigo.png)
